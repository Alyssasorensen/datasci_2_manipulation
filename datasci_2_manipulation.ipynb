# %% [markdown]
# <a href="https://colab.research.google.com/github/Alyssasorensen/datasci_2_manipulation/blob/main/datasci_2_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning
#
# For this week's homework, I will be data cleaning with Pandas, performing data transformation, and displaying alternative libraries.

# %% [markdown]
# ### Load Packages

# %%
import pandas as pd

# %% [markdown]
# ### Load Data

# %%
healthcare_data_cleaning = pd.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')

# %%
healthcare_data_cleaning
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %%
data_types= healthcare_data_cleaning.dtypes
data_types
# Out:
# Patient Age              object
# Gender                   object
# City of Residence        object
# State of Residence       object
# Has Insurance            object
# Visited Last Month       object
# Payment Method           object
# Preferred Doctor         object
# Disease Diagnosed        object
# Medication Prescribed    object
# Type of Appointment      object
# Average Heart Rate       object
# Average BP               object
# Height (in cm)           object
# Weight (in kg)           object
# Payment Due ($)          object
# Last Visit (days ago)    object
# Visit Duration (mins)    object
# Number of Tests          object
# Prescription Cost ($)    object
# dtype: object

# %% [markdown]
# ### Removing Duplicate Rows

# %%
healthcare_data_cleaning.drop_duplicates(inplace=True)
healthcare_data_cleaning
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %%
print(healthcare_data_cleaning.columns)
# Out:
# Index(['Patient Age', 'Gender', 'City of Residence', 'State of Residence',
#        'Has Insurance', 'Visited Last Month', 'Payment Method',
#        'Preferred Doctor', 'Disease Diagnosed', 'Medication Prescribed',
#        'Type of Appointment', 'Average Heart Rate', 'Average BP',
#        'Height (in cm)', 'Weight (in kg)', 'Payment Due ($)',
#        'Last Visit (days ago)', 'Visit Duration (mins)', 'Number of Tests',
#        'Prescription Cost ($)'],
#       dtype='object')

# %%
healthcare_data_cleaning['Payment Due ($)'] = healthcare_data_cleaning['Payment Due ($)'].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-c294310c7ffe> in <cell line: 1>()
# ----> 1 healthcare_data_cleaning['Payment Due ($)'] = healthcare_data_cleaning['Payment Due ($)'].astype(str).astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
healthcare_data_cleaning['Payment Due ($)'] = healthcare_data_cleaning['Payment Due ($)'].astype(str).astype(float)
healthcare_data_cleaning['Prescription Cost ($)'] = healthcare_data_cleaning['Prescription Cost ($)'].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-58f3532d27ea> in <cell line: 1>()
# ----> 1 healthcare_data_cleaning['Payment Due ($)'] = healthcare_data_cleaning['Payment Due ($)'].astype(str).astype(float)
#       2 healthcare_data_cleaning['Prescription Cost ($)'] = healthcare_data_cleaning['Prescription Cost ($)'].astype(str).astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
# ...

# %% [markdown]
# ### Removing White Space and Special Characters

# %%
import pandas as pd
import re
import numpy as np

# %%
def clean_value(value):
    cleaned_value = re.sub(r'\s+|[^a-zA-Z0-9]', '', value)
    return cleaned_value

# Apply the clean_value function to all columns
for column in healthcare_data_cleaning.columns:
    healthcare_data_cleaning[column] = healthcare_data_cleaning[column].apply(clean_value)

healthcare_data_cleaning
# Out:
#        Patient Age  Gender City of Residence State of Residence Has Insurance  \
# 0               45   Other         WestBrian           Kentucky           Yes
# 1               25  Female   EastJocelynfurt           Colorado            No
# 2               51   Other  SouthLindseyland               Ohio           Yes
# 3               18  Female        Taylorfort       Pennsylvania           Yes
# 4               48  Female         Birdmouth            Montana            No
# ...            ...     ...               ...                ...           ...
# 104994          53  Female     Michelleburgh        SouthDakota            No
# 104995          74   Other       WestAnthony           Oklahoma           Yes
# 104996          37    Male         Mckeetown               Utah           Yes
# 104997          51  Female   LakeLisachester           Nebraska           Yes
# 104998     missing  Female      Heidiborough            missing           Yes
#
# ...

# %% [markdown]
# ### Adding the Decimals Back to the "Payment Due" Column and "Prescription Cost" Column

# %%
import pandas as pd

# Sample DataFrame with cleaned money amounts (without decimals)
data = {'Payment Due ($)': [65.45721578126224, 430.68365678679174, 315.0709305262176, 320.2998987723972, 264.2147372473319]}
df = pd.DataFrame(data)

# Number of decimal places to round
decimal_places = 2

# Function to round numbers to the specified decimal places
def round_to_decimal_places(value, decimal_places):
    return round(value, decimal_places)

# Apply the rounding function to the 'Amount' column
df['Payment Due ($)'] = df['Payment Due ($)'].apply(lambda x: round_to_decimal_places(x, decimal_places))

# Display the corrected DataFrame
df
# Out:
#    Payment Due ($)
# 0            65.46
# 1           430.68
# 2           315.07
# 3           320.30
# 4           264.21

# %%
import re
import numpy as np

# %%
healthcare_data_cleaning['Payment Due ($)'] = pd.to_numeric(healthcare_data_cleaning['Payment Due ($)'], errors='coerce')
healthcare_data_cleaning['prescription_cost_$'] = pd.to_numeric(healthcare_data_cleaning['prescription_cost_$'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'payment_due_$'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
healthcare_data_cleaning['age'] = pd.to_numeric(healthcare_data_cleaning['age'], errors='coerce')
healthcare_data_cleaning['average_heart_rate'] = pd.to_numeric(healthcare_data_cleaning['average_heart_rate'], errors='coerce')
healthcare_data_cleaning['average_bp'] = pd.to_numeric(healthcare_data_cleaning['average_bp'], errors='coerce')

# %% [markdown]
# ### Handling Missing Values

# %%
healthcare_data_cleaning = healthcare_data_cleaning.replace('missing','Unknown')
healthcare_data_cleaning
# Out:
#        Patient Age  Gender City of Residence State of Residence Has Insurance  \
# 0               45   Other         WestBrian           Kentucky           Yes
# 1               25  Female   EastJocelynfurt           Colorado            No
# 2               51   Other  SouthLindseyland               Ohio           Yes
# 3               18  Female        Taylorfort       Pennsylvania           Yes
# 4               48  Female         Birdmouth            Montana            No
# ...            ...     ...               ...                ...           ...
# 104994          53  Female     Michelleburgh        SouthDakota            No
# 104995          74   Other       WestAnthony           Oklahoma           Yes
# 104996          37    Male         Mckeetown               Utah           Yes
# 104997          51  Female   LakeLisachester           Nebraska           Yes
# 104998     Unknown  Female      Heidiborough            Unknown           Yes
#
# ...

# %% [markdown]
# ### Cleaning Column Names

# %%
healthcare_data_cleaning.columns = healthcare_data_cleaning.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
healthcare_data_cleaning
# Out:
# <ipython-input-18-bde3266830c7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   healthcare_data_cleaning.columns = healthcare_data_cleaning.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# <ipython-input-18-bde3266830c7>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   healthcare_data_cleaning.columns = healthcare_data_cleaning.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#        patient_age  gender city_of_residence state_of_residence has_insurance  \
# 0               45   Other         WestBrian           Kentucky           Yes
# ...

# %% [markdown]
# ### Summary of the Changes Made

# %% [markdown]
# #### Need to add**

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Creating New Columns Based on Existing Ones

# %%
healthcare_data_cleaning.rename(columns = {'patient_age':'age', 'city_of_residence': 'city', 'state_of_residence': 'state', 'disease_diagnosed':'diagnosis', 'medication_prescribed': 'prescription', 'height_in_cm': 'height_cm', 'weight_in_kg':'weight_kg'}, inplace = True)
healthcare_data_cleaning
# Out:
#             age  gender              city         state has_insurance  \
# 0            45   Other         WestBrian      Kentucky           Yes
# 1            25  Female   EastJocelynfurt      Colorado            No
# 2            51   Other  SouthLindseyland          Ohio           Yes
# 3            18  Female        Taylorfort  Pennsylvania           Yes
# 4            48  Female         Birdmouth       Montana            No
# ...         ...     ...               ...           ...           ...
# 104994       53  Female     Michelleburgh   SouthDakota            No
# 104995       74   Other       WestAnthony      Oklahoma           Yes
# 104996       37    Male         Mckeetown          Utah           Yes
# 104997       51  Female   LakeLisachester      Nebraska           Yes
# 104998  Unknown  Female      Heidiborough       Unknown           Yes
#
#        visited_last_month payment_method preferred_doctor diagnosis  \
# ...

# %% [markdown]
# ### Aggregating Data Using Groupby and Compute Summary Statistics

# %%
healthcare_data_cleaning['diagnosis'].value_counts()
# Out:
# Flu        19123
# Allergy    19063
# None       19021
# Cold       18962
# Covid19    18831
# Unknown     5000
# Name: diagnosis, dtype: int64

# %%
encompass_diagnosis = healthcare_data_cleaning[healthcare_data_cleaning['diagnosis'] == 'Flu']
encompass_diagnosis.groupby(['diagnosis']).sum()
# Out:
#                                                          age  \
# diagnosis
# Flu        4525185220543962457239544458364262492540323746...
#
#                                                       gender  \
# diagnosis
# Flu        OtherFemaleFemaleMaleFemaleFemaleMaleOtherMale...
#
#                                                         city  \
# diagnosis
# Flu        WestBrianEastJocelynfurtTaylorfortVanessaburgh...
#
#                                                        state  \
# diagnosis
# Flu        KentuckyColoradoPennsylvaniaConnecticutMontana...
#
#                                                has_insurance  \
# diagnosis
# Flu        YesNoYesYesNoYesNoNoNoNoYesNoNoYesYesYesYesNoN...
#
#                                           visited_last_month  \
# diagnosis
# Flu        YesYesUnknownYesYesYesYesYesNoYesYesNoYesNoYes...
#
#                                               payment_method  \
# diagnosis
# Flu        InsuranceCardCashInsuranceCardCashUnknownCashC...
# ...

# %%
healthcare_data_cleaning
# Out:
#             age  gender              city         state has_insurance  \
# 0            45   Other         WestBrian      Kentucky           Yes
# 1            25  Female   EastJocelynfurt      Colorado            No
# 2            51   Other  SouthLindseyland          Ohio           Yes
# 3            18  Female        Taylorfort  Pennsylvania           Yes
# 4            48  Female         Birdmouth       Montana            No
# ...         ...     ...               ...           ...           ...
# 104994       53  Female     Michelleburgh   SouthDakota            No
# 104995       74   Other       WestAnthony      Oklahoma           Yes
# 104996       37    Male         Mckeetown          Utah           Yes
# 104997       51  Female   LakeLisachester      Nebraska           Yes
# 104998  Unknown  Female      Heidiborough       Unknown           Yes
#
#        visited_last_month payment_method preferred_doctor diagnosis  \
# ...

# %%
healthcare_data_cleaning.columns
# Out:
# Index(['age', 'gender', 'city', 'state', 'has_insurance', 'visited_last_month',
#        'payment_method', 'preferred_doctor', 'diagnosis', 'prescription',
#        'type_of_appointment', 'average_heart_rate', 'average_bp', 'height_cm',
#        'weight_kg', 'payment_due_$', 'last_visit_days_ago',
#        'visit_duration_mins', 'number_of_tests', 'prescription_cost_$'],
#       dtype='object')

# %%
data = pd.DataFrame({
    'bad Row': [1, 2, 3],
    'another bad row': [3, 2, 1]
})
data
# Out:
#    bad Row  another bad row
# 0        1                3
# 1        2                2
# 2        3                1

# %%
healthcare_data_cleaning.dtypes

healthcare_data_cleaning['state'] = str(healthcare_data_cleaning['state'])

healthcare_data_cleaning.dtypes
# Out:
# age                    object
# gender                 object
# city                   object
# state                  object
# has_insurance          object
# visited_last_month     object
# payment_method         object
# preferred_doctor       object
# diagnosis              object
# prescription           object
# type_of_appointment    object
# average_heart_rate     object
# average_bp             object
# height_cm              object
# weight_kg              object
# payment_due_$          object
# last_visit_days_ago    object
# visit_duration_mins    object
# number_of_tests        object
# prescription_cost_$    object
# dtype: object

# %%
import pandas as pd

data = pd.DataFrame({
    'Bad Row 1': [1, 2],
    'Bad Row 2': [3, 4]
})

print(data)

# Function to remove white space and special characters from a value
def clean_column(column):
    # Convert integers to strings
    column = column.astype(str)

    # Remove white space and special characters, and convert to lowercase
    column = column.str.replace(r'[^a-zA-Z0-9]', '', regex=True)
    column = column.str.lower()
    return column

# Apply the clean_column function to all columns
for column in data.columns:
    data[column] = clean_column(data[column])

print(data)
# Out:
#    Bad Row 1  Bad Row 2
# 0          1          3
# 1          2          4
#   Bad Row 1 Bad Row 2
# 0         1         3
# 1         2         4
