# %% [markdown]
# <a href="https://colab.research.google.com/github/Alyssasorensen/datasci_2_manipulation/blob/main/datasci_2_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning
#
# For this week's homework, I will be data cleaning with Pandas, performing data transformation, and displaying alternative libraries.

# %% [markdown]
# ### Loading Pandas Packages

# %%
import pandas as pd

# %% [markdown]
# ### Loading Data

# %%
healthcare_data_cleaning = pd.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')

# %%
healthcare_data_cleaning
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %%
data_types= healthcare_data_cleaning.dtypes
data_types
# Out:
# Patient Age              object
# Gender                   object
# City of Residence        object
# State of Residence       object
# Has Insurance            object
# Visited Last Month       object
# Payment Method           object
# Preferred Doctor         object
# Disease Diagnosed        object
# Medication Prescribed    object
# Type of Appointment      object
# Average Heart Rate       object
# Average BP               object
# Height (in cm)           object
# Weight (in kg)           object
# Payment Due ($)          object
# Last Visit (days ago)    object
# Visit Duration (mins)    object
# Number of Tests          object
# Prescription Cost ($)    object
# dtype: object

# %% [markdown]
# ### Removing Duplicate Rows

# %%
healthcare_data_cleaning.drop_duplicates(inplace=True)
healthcare_data_cleaning
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ### Removing White Space and Special Characters

# %%
import re  # Import the 're' module

# Function to remove white space and special characters from a value
def clean_column_names(df):
    # Define a helper function to clean column names
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    # Rename columns using the helper function
    # This is using a list comprehension - e.g., we have a list to the right of the equals sign,
    # and inside the list, we are applying our function for every col (or X) that exists in df.columns
    healthcare_data_cleaning.columns = [clean_name(col) for col in healthcare_data_cleaning.columns]  # Use 'df' instead of 'healthcare_data_cleaning'
    return healthcare_data_cleaning

# Apply the clean_column_names function to all columns
data_types = clean_column_names(data_types)

print(data_types)
# Out:
#        patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0              45   Other         West Brian         Kentucky          Yes
# 1              25  Female   East Jocelynfurt         Colorado           No
# 2              51   Other  South Lindseyland             Ohio          Yes
# 3              18  Female         Taylorfort     Pennsylvania          Yes
# 4              48  Female          Birdmouth          Montana           No
# ...           ...     ...                ...              ...          ...
# 104994         53  Female      Michelleburgh     South Dakota           No
# 104995         74   Other       West Anthony         Oklahoma          Yes
# 104996         37    Male          Mckeetown             Utah          Yes
# 104997         51  Female   Lake Lisachester         Nebraska          Yes
# 104998    missing  Female       Heidiborough          missing          Yes
#
# ...

# %% [markdown]
# ### Adding the Decimals Back to the "Payment Due" Column and "Prescription Cost" Column

# %%
import re
import numpy as np

# %%
healthcare_data_cleaning['paymentdue'] = pd.to_numeric(healthcare_data_cleaning['paymentdue'], errors='coerce')
healthcare_data_cleaning['prescriptioncost'] = pd.to_numeric(healthcare_data_cleaning['prescriptioncost'], errors='coerce')

# %%
healthcare_data_cleaning['patientage'] = pd.to_numeric(healthcare_data_cleaning['patientage'], errors='coerce')
healthcare_data_cleaning['averageheartrate'] = pd.to_numeric(healthcare_data_cleaning['averageheartrate'], errors='coerce')
healthcare_data_cleaning['averagebp'] = pd.to_numeric(healthcare_data_cleaning['averagebp'], errors='coerce')
healthcare_data_cleaning['heightincm'] = pd.to_numeric(healthcare_data_cleaning['heightincm'], errors='coerce')
healthcare_data_cleaning['weightinkg'] = pd.to_numeric(healthcare_data_cleaning['weightinkg'], errors='coerce')

# %%
healthcare_data_cleaning['lastvisitdaysago'] = pd.to_numeric(healthcare_data_cleaning['lastvisitdaysago'], errors='coerce')
healthcare_data_cleaning['visitdurationmins'] = pd.to_numeric(healthcare_data_cleaning['visitdurationmins'], errors='coerce')
healthcare_data_cleaning['numberoftests'] = pd.to_numeric(healthcare_data_cleaning['numberoftests'], errors='coerce')

# %% [markdown]
# ### Handling Missing Values

# %%
print(data_types['patientage'].value_counts())
# Out:
# patientage
# 18.0     4047
# 47.0     2555
# 45.0     2543
# 44.0     2529
# 42.0     2518
#          ...
# 100.0      10
# 96.0       10
# 97.0        8
# 99.0        7
# 98.0        5
# Name: count, Length: 83, dtype: int64

# %%
print(data_types['gender'].value_counts())
# Out:
# gender
# Male       31728
# Female     31674
# Other      31598
# missing     5000
# Name: count, dtype: int64

# %%
print(data_types['cityofresidence'].value_counts())
# Out:
# cityofresidence
# missing              5000
# Lake Michael          100
# West Michael           82
# East Michael           77
# Port Michael           74
#                      ...
# Deleontown              1
# Lake Hollychester       1
# Port Edwardhaven        1
# West Pamelaton          1
# Mckeetown               1
# Name: count, Length: 37133, dtype: int64

# %%
print(data_types['stateofresidence'].value_counts())
# Out:
# stateofresidence
# missing           5000
# New Mexico        1969
# Nevada            1969
# Idaho             1965
# Massachusetts     1959
# California        1952
# Ohio              1950
# Connecticut       1950
# Kentucky          1946
# North Carolina    1944
# New Jersey        1932
# Alaska            1927
# Wisconsin         1926
# Nebraska          1922
# Rhode Island      1918
# Minnesota         1918
# Wyoming           1917
# West Virginia     1916
# Arizona           1915
# Tennessee         1914
# South Carolina    1912
# North Dakota      1911
# Virginia          1911
# Utah              1910
# Kansas            1909
# Pennsylvania      1908
# Missouri          1906
# Iowa              1906
# Montana           1904
# Mississippi       1897
# Florida           1893
# Louisiana         1893
# Illinois          1891
# New York          1891
# Oregon            1888
# Indiana           1886
# Vermont           1885
# Texas             1876
# Oklahoma          1876
# ...

# %%
print(data_types['hasinsurance'].value_counts())
# Out:
# hasinsurance
# Yes        47597
# No         47403
# missing     5000
# Name: count, dtype: int64

# %%
print(data_types['visitedlastmonth'].value_counts())
# Out:
# visitedlastmonth
# No         47572
# Yes        47428
# missing     5000
# Name: count, dtype: int64

# %%
print(data_types['paymentmethod'].value_counts())
# Out:
# paymentmethod
# Card         31744
# Insurance    31662
# Cash         31594
# missing       5000
# Name: count, dtype: int64

# %%
print(data_types['preferreddoctor'].value_counts())
# Out:
# preferreddoctor
# Dr. Jones       19153
# Dr. Williams    19078
# Dr. Johnson     19005
# Dr. Smith       18914
# Dr. Brown       18850
# missing          5000
# Name: count, dtype: int64

# %%
print(data_types['diseasediagnosed'].value_counts())
# Out:
# diseasediagnosed
# Flu         19123
# Allergy     19063
# Cold        18962
# Covid-19    18831
# missing      5000
# Name: count, dtype: int64

# %%
print(data_types['medicationprescribed'].value_counts())
# Out:
# medicationprescribed
# Med_C      19149
# Med_D      19040
# Med_B      19003
# Med_A      18957
# Med_E      18851
# missing     5000
# Name: count, dtype: int64

# %%
print(data_types['typeofappointment'].value_counts())
# Out:
# typeofappointment
# Specialist    23841
# Follow-Up     23832
# Emergency     23737
# General       23590
# missing        5000
# Name: count, dtype: int64

# %%
print(data_types['averageheartrate'].value_counts())
# Out:
# averageheartrate
# 80.0     3779
# 81.0     3769
# 78.0     3764
# 77.0     3711
# 82.0     3694
#          ...
# 114.0      11
# 116.0       6
# 120.0       4
# 117.0       3
# 119.0       1
# Name: count, Length: 70, dtype: int64

# %%
print(data_types['averagebp'].value_counts())
# Out:
# averagebp
# 80.0     2560
# 110.0    2509
# 109.0    2509
# 112.0    2491
# 111.0    2489
#          ...
# 82.0      489
# 137.0     465
# 81.0      425
# 138.0     415
# 139.0     374
# Name: count, Length: 61, dtype: int64

# %%
print(data_types['heightincm'].value_counts())
# Out:
# heightincm
# 174.0    3834
# 175.0    3767
# 176.0    3731
# 177.0    3727
# 173.0    3702
#          ...
# 142.0      19
# 207.0      17
# 141.0      15
# 208.0      12
# 209.0      11
# Name: count, Length: 71, dtype: int64

# %%
print(data_types['weightinkg'].value_counts())
# Out:
# weightinkg
# 71.0     2559
# 40.0     2544
# 67.0     2532
# 72.0     2526
# 69.0     2481
#          ...
# 134.0       1
# 130.0       1
# 132.0       1
# 128.0       1
# 135.0       1
# Name: count, Length: 93, dtype: int64

# %%
print(data_types['paymentdue'].value_counts())
# Out:
# paymentdue
# 65.457216     1
# 299.988500    1
# 150.184654    1
# 297.964090    1
# 29.961924     1
#              ..
# 471.830263    1
# 456.186160    1
# 273.771756    1
# 315.289042    1
# 5.341231      1
# Name: count, Length: 95000, dtype: int64

# %%
print(data_types['lastvisitdaysago'].value_counts())
# Out:
# lastvisitdaysago
# 183.0    3992
# 182.0    3985
# 184.0    3927
# 180.0    3789
# 185.0    3777
#          ...
# 223.0       2
# 140.0       1
# 220.0       1
# 221.0       1
# 222.0       1
# Name: count, Length: 81, dtype: int64

# %%
print(data_types['visitdurationmins'].value_counts())
# Out:
# visitdurationmins
# 49.0     931
# 69.0     924
# 68.0     917
# 27.0     914
# 36.0     906
#         ...
# 98.0     816
# 109.0    809
# 87.0     808
# 67.0     804
# 107.0    802
# Name: count, Length: 111, dtype: int64

# %%
print(data_types['numberoftests'].value_counts())
# Out:
# numberoftests
# 4.0     23795
# 3.0     20400
# 5.0     19094
# 2.0     11541
# 6.0     10566
# 7.0      3993
# 1.0      3925
# 8.0       979
# 0.0       537
# 9.0       160
# 10.0       10
# Name: count, dtype: int64

# %%
print(data_types['prescriptioncost'].value_counts())
# Out:
# prescriptioncost
# 15.717517     1
# 65.992965     1
# 134.851044    1
# 67.139600     1
# 4.058180      1
#              ..
# 86.083105     1
# 50.488526     1
# 78.533369     1
# 124.019842    1
# 124.408341    1
# Name: count, Length: 95000, dtype: int64

# %%
missing_values = healthcare_data_cleaning.isnull().sum()
missing_values
# Out:
# patientage               5000
# gender                      0
# cityofresidence             0
# stateofresidence            0
# hasinsurance                0
# visitedlastmonth            0
# paymentmethod               0
# preferreddoctor             0
# diseasediagnosed        19021
# medicationprescribed        0
# typeofappointment           0
# averageheartrate         5000
# averagebp                5000
# heightincm               5000
# weightinkg               5000
# paymentdue               5000
# lastvisitdaysago         5000
# visitdurationmins        5000
# numberoftests            5000
# prescriptioncost         5000
# dtype: int64

# %%
healthcare_data_cleaning = healthcare_data_cleaning.replace('missing', 'Unknown')
healthcare_data_cleaning
# Out:
#         patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other         West Brian         Kentucky          Yes
# 1             25.0  Female   East Jocelynfurt         Colorado           No
# 2             51.0   Other  South Lindseyland             Ohio          Yes
# 3             18.0  Female         Taylorfort     Pennsylvania          Yes
# 4             48.0  Female          Birdmouth          Montana           No
# ...            ...     ...                ...              ...          ...
# 104994        53.0  Female      Michelleburgh     South Dakota           No
# 104995        74.0   Other       West Anthony         Oklahoma          Yes
# 104996        37.0    Male          Mckeetown             Utah          Yes
# 104997        51.0  Female   Lake Lisachester         Nebraska          Yes
# 104998         NaN  Female       Heidiborough          Unknown          Yes
#
# ...

# %% [markdown]
# ### Cleaning Column Names

# %%
healthcare_data_cleaning.columns = healthcare_data_cleaning.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
healthcare_data_cleaning
# Out:
#         patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other         West Brian         Kentucky          Yes
# 1             25.0  Female   East Jocelynfurt         Colorado           No
# 2             51.0   Other  South Lindseyland             Ohio          Yes
# 3             18.0  Female         Taylorfort     Pennsylvania          Yes
# 4             48.0  Female          Birdmouth          Montana           No
# ...            ...     ...                ...              ...          ...
# 104994        53.0  Female      Michelleburgh     South Dakota           No
# 104995        74.0   Other       West Anthony         Oklahoma          Yes
# 104996        37.0    Male          Mckeetown             Utah          Yes
# 104997        51.0  Female   Lake Lisachester         Nebraska          Yes
# 104998         NaN  Female       Heidiborough          Unknown          Yes
#
# ...

# %% [markdown]
# ### Summary of the Changes Made

# %% [markdown]
# ##### The initial step involved loading the packages into Google Colab. This meant that I needed to write "import pandas as pd." Following this, I had to load the data. I inserted the CSV file from GitHub and Google Colab displayed the data. After this, I removed duplicate rows from the DataFrame. This was done by inserting, "healthcare_data_cleaning.drop_duplicates(inplace=True)." The "drop_duplicates" identifies and removes duplicate rows from the DataFrame based on the columns' values by default. The statement "inplace=True" is an argument passed to the "drop_duplicates" method. When "inplace=True" is set, it means the operation wil be performed directly on the original DataFrame, which is healthcare_data_cleaning. After this, I removed white spaces and special characters. The function inserted for this was used to ensure that column names in the DataFrame do not contain non-alphanumeric characters, white spaces, and are standardized to lowercase, which can be helpful for consistency. Next, I added the decimals back to the values of payment due and prescription cost columns. Next, I handled the missing values from the DataFrame. I did this by inserting "print(data_types['patientage'].value_counts())." Following this, I cleaned some of the column names by changing how they are displayed in the DataFrame.

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### Creating New Columns Based on Existing Ones

# %%
healthcare_data_cleaning.rename(columns = {'patient_age':'age', 'city_of_residence': 'city', 'state_of_residence': 'state', 'disease_diagnosed':'diagnosis', 'medication_prescribed': 'prescription', 'height_in_cm': 'height_cm', 'weight_in_kg':'weight_kg'}, inplace = True)
healthcare_data_cleaning
# Out:
#         patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other         West Brian         Kentucky          Yes
# 1             25.0  Female   East Jocelynfurt         Colorado           No
# 2             51.0   Other  South Lindseyland             Ohio          Yes
# 3             18.0  Female         Taylorfort     Pennsylvania          Yes
# 4             48.0  Female          Birdmouth          Montana           No
# ...            ...     ...                ...              ...          ...
# 104994        53.0  Female      Michelleburgh     South Dakota           No
# 104995        74.0   Other       West Anthony         Oklahoma          Yes
# 104996        37.0    Male          Mckeetown             Utah          Yes
# 104997        51.0  Female   Lake Lisachester         Nebraska          Yes
# 104998         NaN  Female       Heidiborough          Unknown          Yes
#
# ...

# %% [markdown]
# ### Aggregating Data Using Groupby and Compute Summary Statistics

# %%
healthcare_data_cleaning['diseasediagnosed'].value_counts()
# Out:
# diseasediagnosed
# Flu         19123
# Allergy     19063
# Cold        18962
# Covid-19    18831
# Unknown      5000
# Name: count, dtype: int64

# %%
encompass_diagnosis = healthcare_data_cleaning[healthcare_data_cleaning['diseasediagnosed'] == 'Flu']
encompass_diagnosis.groupby(['diseasediagnosed']).sum()
# Out:
#                   patientage  \
# diseasediagnosed
# Flu                 811046.0
#
#                                                              gender  \
# diseasediagnosed
# Flu               OtherFemaleFemaleMaleFemaleFemaleMaleOtherMale...
#
#                                                     cityofresidence  \
# diseasediagnosed
# Flu               West BrianEast JocelynfurtTaylorfortVanessabur...
#
#                                                    stateofresidence  \
# diseasediagnosed
# Flu               KentuckyColoradoPennsylvaniaConnecticutMontana...
#
#                                                        hasinsurance  \
# diseasediagnosed
# Flu               YesNoYesYesNoYesNoNoNoNoYesNoNoYesYesYesYesNoN...
#
#                                                    visitedlastmonth  \
# diseasediagnosed
# Flu               YesYesUnknownYesYesYesYesYesNoYesYesNoYesNoYes...
#
#                                                       paymentmethod  \
# diseasediagnosed
# ...

# %%
healthcare_data_cleaning
# Out:
#         patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other         West Brian         Kentucky          Yes
# 1             25.0  Female   East Jocelynfurt         Colorado           No
# 2             51.0   Other  South Lindseyland             Ohio          Yes
# 3             18.0  Female         Taylorfort     Pennsylvania          Yes
# 4             48.0  Female          Birdmouth          Montana           No
# ...            ...     ...                ...              ...          ...
# 104994        53.0  Female      Michelleburgh     South Dakota           No
# 104995        74.0   Other       West Anthony         Oklahoma          Yes
# 104996        37.0    Male          Mckeetown             Utah          Yes
# 104997        51.0  Female   Lake Lisachester         Nebraska          Yes
# 104998         NaN  Female       Heidiborough          Unknown          Yes
#
# ...

# %%
encompass_diagnosis = healthcare_data_cleaning[healthcare_data_cleaning['diseasediagnosed'] == 'Covid-19']
encompass_diagnosis.groupby(['diseasediagnosed']).sum()
# Out:
#                   patientage  \
# diseasediagnosed
# Covid-19            796229.0
#
#                                                              gender  \
# diseasediagnosed
# Covid-19          OtherUnknownMaleFemaleMaleFemaleMaleUnknownOth...
#
#                                                     cityofresidence  \
# diseasediagnosed
# Covid-19          South LindseylandNorth DonaldLake JenniferJone...
#
#                                                    stateofresidence  \
# diseasediagnosed
# Covid-19          OhioOklahomaUnknownRhode IslandOregonNew Mexic...
#
#                                                        hasinsurance  \
# diseasediagnosed
# Covid-19          YesNoNoNoYesNoYesNoNoUnknownYesNoUnknownNoYesN...
#
#                                                    visitedlastmonth  \
# diseasediagnosed
# Covid-19          NoYesNoNoYesYesYesNoYesYesNoYesNoNoNoYesYesYes...
#
#                                                       paymentmethod  \
# diseasediagnosed
# ...

# %%
healthcare_data_cleaning
# Out:
#         patientage  gender    cityofresidence stateofresidence hasinsurance  \
# 0             45.0   Other         West Brian         Kentucky          Yes
# 1             25.0  Female   East Jocelynfurt         Colorado           No
# 2             51.0   Other  South Lindseyland             Ohio          Yes
# 3             18.0  Female         Taylorfort     Pennsylvania          Yes
# 4             48.0  Female          Birdmouth          Montana           No
# ...            ...     ...                ...              ...          ...
# 104994        53.0  Female      Michelleburgh     South Dakota           No
# 104995        74.0   Other       West Anthony         Oklahoma          Yes
# 104996        37.0    Male          Mckeetown             Utah          Yes
# 104997        51.0  Female   Lake Lisachester         Nebraska          Yes
# 104998         NaN  Female       Heidiborough          Unknown          Yes
#
# ...

# %%
healthcare_data_cleaning.columns
# Out:
# Index(['patientage', 'gender', 'cityofresidence', 'stateofresidence',
#        'hasinsurance', 'visitedlastmonth', 'paymentmethod', 'preferreddoctor',
#        'diseasediagnosed', 'medicationprescribed', 'typeofappointment',
#        'averageheartrate', 'averagebp', 'heightincm', 'weightinkg',
#        'paymentdue', 'lastvisitdaysago', 'visitdurationmins', 'numberoftests',
#        'prescriptioncost'],
#       dtype='object')

# %%
pivot_table = healthcare_data_cleaning.pivot_table(index='patientage', columns='gender', values='numberoftests', aggfunc='mean')
pivot_table
# Out:
# gender        Female      Male     Other   Unknown
# patientage
# 18.0        4.005710  4.031771  3.976311  4.031414
# 19.0        3.994872  3.969880  4.072917  3.884615
# 20.0        4.044118  3.943590  3.905941  4.000000
# 21.0        4.004098  4.152466  4.008368  4.268293
# 22.0        4.042636  3.886878  3.882562  3.745455
# ...              ...       ...       ...       ...
# 96.0        3.750000  3.000000  4.750000       NaN
# 97.0        4.666667  4.000000  4.000000  3.000000
# 98.0        4.500000  2.000000       NaN  7.000000
# 99.0        5.000000  2.500000  5.000000       NaN
# 100.0            NaN  5.166667  5.000000       NaN
#
# [83 rows x 4 columns]

# %%
pivot_table = healthcare_data_cleaning.pivot_table(index='gender', columns='hasinsurance', values='paymentdue', aggfunc='mean')
pivot_table
# Out:
# hasinsurance          No     Unknown         Yes
# gender
# Female        248.505546  249.640663  249.048480
# Male          251.145420  246.216726  249.736330
# Other         248.469690  252.076968  250.898797
# Unknown       249.741155  251.416699  255.595722

# %%
pivot_table = healthcare_data_cleaning.pivot_table(index='diseasediagnosed', columns='typeofappointment', values='prescriptioncost', aggfunc='mean')
pivot_table
# Out:
# typeofappointment  Emergency  Follow-Up    General  Specialist    Unknown
# diseasediagnosed
# Allergy            74.661355  75.737521  74.566674   74.845884  73.246786
# Cold               74.479360  75.168171  74.869570   75.225813  75.269402
# Covid-19           74.155488  75.477123  74.875238   75.255247  74.074811
# Flu                75.498899  74.150736  74.609996   75.972985  73.410834
# Unknown            72.860005  75.094282  76.008557   73.818379  72.771497

# %% [markdown]
# # Introduction to Alternative Libraries

# %% [markdown]
# ### Loading Polars Package

# %%
import polars as pl

# %% [markdown]
# ### Loading Data for Polars

# %%
healthcare_data_cleaning = pl.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')

# %%
healthcare_data_cleaning
# Out:
# shape: (105_000, 20)
# ┌───────────┬────────┬────────────┬────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ Patient   ┆ Gender ┆ City of    ┆ State of   ┆ … ┆ Last Visit ┆ Visit      ┆ Number of  ┆ Prescripti │
# │ Age       ┆ ---    ┆ Residence  ┆ Residence  ┆   ┆ (days ago) ┆ Duration   ┆ Tests      ┆ on Cost    │
# │ ---       ┆ str    ┆ ---        ┆ ---        ┆   ┆ ---        ┆ (mins)     ┆ ---        ┆ ($)        │
# │ str       ┆        ┆ str        ┆ str        ┆   ┆ str        ┆ ---        ┆ str        ┆ ---        │
# │           ┆        ┆            ┆            ┆   ┆            ┆ str        ┆            ┆ str        │
# ╞═══════════╪════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 45        ┆ Other  ┆ West Brian ┆ Kentucky   ┆ … ┆ 193        ┆ 92         ┆ 5          ┆ 15.7175173 │
# │           ┆        ┆            ┆            ┆   ┆            ┆            ┆            ┆ 5532889    │
# ...

# %%
import polars as pl

healthcare_data_cleaning = pl.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')

print("Number of rows:", healthcare_data_cleaning.shape[0])
print("Number of columns:", healthcare_data_cleaning.shape[1])
# Out:
# Number of rows: 105000
# Number of columns: 20

# %%
import time

# %%
dataset_path = 'healthcare_data_cleaning.csv'

# %%
start_time = time.time()
polars_healthcare_data_cleaning = pd.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')
polars_filtered = polars_healthcare_data_cleaning[polars_healthcare_data_cleaning['Gender'] == 'Male']
polars_average_age = polars_filtered['Average BP'].sum()
polars_time = time.time() - start_time

# %% [markdown]
# ### Loading Modin Package

# %%
pip install "modin[all]"

# %%
pip install --upgrade pandas
# Out:
# ...
#   Using cached pandas-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.0 which is incompatible.
# modin 0.23.1 requires pandas<2.1,>=2, but you have pandas 2.1.0 which is incompatible.
# ...

# %%
pip install --upgrade modin
# Out:
# ...
#   Using cached pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.0
#     Uninstalling pandas-2.1.0:
#       Successfully uninstalled pandas-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# ...

# %%
pip install botocore

# %%
pip install -U modin

# %%
# Post-install automatically kill and restart Colab environment
import os

# %%
os.kill(os.getpid(), 9)

# %%
# import pandas as pd
import modin.pandas as pd

# %%
import modin.pandas as mpd

# %%
import modin.pandas as mpd
import requests

url = 'https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv'
response = requests.get(url)

# Save the file locally
with open('healthcare_data.csv', 'wb') as file:
    file.write(response.content)

# Read the downloaded file
healthcare_data_cleaning = mpd.read_csv('healthcare_data.csv')
# Out:
# ...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     import ray
#     ray.init()
#
# ...
# 2023-09-09 22:32:27,708	INFO worker.py:1621 -- Started a local Ray instance.

# %%
# Create a Modin DataFrame from a CSV file containing healthcare data
# For example, we have patient records with columns like 'Patient Age', 'Gender', 'City of Residence', 'Disease Diagnosed'
healthcare_data_cleaning = mpd.read_csv('healthcare_data.csv')

# %%
# Display the first few rows of the Modin DataFrame
print(healthcare_data_cleaning.head())

# Filter the data to select patients with a specific condition
disease_diagnosed_patients = healthcare_data_cleaning[healthcare_data_cleaning['Disease Diagnosed'] == 'Flu']
# Out:
#   Patient Age  Gender  City of Residence State of Residence Has Insurance  \
# 0          45   Other         West Brian           Kentucky           Yes
# 1          25  Female   East Jocelynfurt           Colorado            No
# 2          51   Other  South Lindseyland               Ohio           Yes
# 3          18  Female         Taylorfort       Pennsylvania           Yes
# 4          48  Female          Birdmouth            Montana            No
#
#   Visited Last Month Payment Method Preferred Doctor Disease Diagnosed  \
# 0                Yes      Insurance     Dr. Williams               Flu
# 1                Yes           Card      Dr. Johnson               Flu
# 2                 No           Cash     Dr. Williams          Covid-19
# 3            missing           Cash     Dr. Williams               Flu
# 4                 No      Insurance        Dr. Brown               NaN
#
#   Medication Prescribed Type of Appointment Average Heart Rate Average BP  \
# ...

# %%
unique_values = disease_diagnosed_patients['Patient Age'].unique()
print(unique_values)
# Out:
# ['45' '25' '18' '52' '20' '54' '39' '62' '72' '44' '58' '36' '42' '49'
#  '40' '32' '37' '46' '34' '50' '22' '78' '66' '48' '19' '64' 'missing'
#  '43' '38' '47' '55' '88' '41' '35' '59' '56' '27' '53' '31' '24' '67'
#  '51' '33' '77' '68' '60' '61' '71' '30' '57' '28' '26' '79' '74' '76'
#  '69' '90' '63' '75' '65' '21' '80' '70' '29' '23' '81' '73' '82' '85'
#  '87' '94' '83' '92' '97' '86' '84' '89' '91' '96' '98' '99' '93' '95']

# %%
disease_diagnosed_patients['Patient Age'] = pd.to_numeric(disease_diagnosed_patients['Patient Age'], errors='coerce')

# %%
# Average age of patients with the flu
average_age = disease_diagnosed_patients['Patient Age'].mean()
print(f"Average age of patients with the flu: {average_age:.2f} years")
# Out:
# Average age of patients with the flu: 44.71 years

# %%
import modin.pandas as mpd
import pandas as pd
import time

# %%
# Define the dataset path
dataset_path = 'healthcare_data_cleaning.csv'

# %% [markdown]
# ### Loading Times

# %%
start_time = time.time()
modin_healthcare_data_cleaning = pd.read_csv('https://raw.githubusercontent.com/Alyssasorensen/datasci_2_manipulation/main/datasets/raw.githubusercontent.com_hantswilliams_HHA_507_2023_main_WK2_data_healthcare_data_cleaning.csv')
modin_filtered = modin_healthcare_data_cleaning[modin_healthcare_data_cleaning['Gender'] == 'Male']
modin_average_age = modin_filtered['Average BP'].sum()
modin_time = time.time() - start_time

# %%
print(f"Modin Execution Time: {modin_time:.4f} seconds")
print(f"Polars Execution Time: {polars_time:.4f} seconds")
# Out:
# Modin Execution Time: 0.5426 seconds
# Polars Execution Time: 0.4323 seconds

# %% [markdown]
# ### Loading Times Observation
# ###### Modin took longer than Polars to execute the code. Modin took 0.5426 seconds and Polars took 0.4323 seconds. Modin took approximately 0.1103 seconds longer to execute the code.
